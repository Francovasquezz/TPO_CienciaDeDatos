# %%
import pandas as pd

# Definimos la ruta al archivo que creamos con el ETL
file_path = '../data/processed/player_stats_Primera_Division_Argentina_2024.parquet'

# Leemos el archivo Parquet con pandas
print("Cargando el archivo Parquet...")
df = pd.read_parquet(file_path)

# ¡Listo! Mostramos las primeras 5 filas para verificar que se cargó bien
print("¡Datos cargados exitosamente! Estas son las primeras 5 filas:")
df.head()
# Out:
# Cargando el archivo Parquet...
# ¡Datos cargados exitosamente! Estas son las primeras 5 filas:
#                   Player stats_Nation stats_Pos      stats_Squad  \
# 0        Aaron Anselmino       ar ARG        DF     Boca Juniors
# 1  Aaron Nicolás Molinas       ar ARG     MF,FW   Defensa y Just
# 2           Aaron Quirós       ar ARG        DF         Banfield
# 3           Aaron Quirós       ar ARG     DF,FW  Vélez Sarsfield
# 4           Abiel Osorio       ar ARG        FW   Defensa y Just
#
#                    stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# 0  Primera Division Argentina        18       2005       12           10
# 1  Primera Division Argentina        23       2000       24           18
# 2  Primera Division Argentina        22       2001        5            5
# 3  Primera Division Argentina        22       2001       10            2
# 4  Primera Division Argentina        21       2002       20            9
#
# ...

# %%
pd.set_option('display.max_columns', None)

# Ahora, si vuelves a pedir una muestra, verás todas las columnas
df.sample(2)
# Out:
#               Player stats_Nation stats_Pos      stats_Squad  \
# 443   Jeremías Lucco       ar ARG     FW,MF         Belgrano
# 434  Jaminton Campaz       co COL     FW,MF  Rosario Central
#
#                      stats_Comp stats_Age stats_Born stats_MP stats_Starts  \
# 443  Primera Division Argentina        18       2005        8            2
# 434  Primera Division Argentina        23       2000       18           13
#
#     stats_Min stats_90s stats_Gls stats_Ast stats_G+A stats_G-PK stats_PK  \
# 443       284       3.2         1         0         1          1        0
# 434     1,101      12.2         3         1         4          3        0
#
#     stats_PKatt stats_CrdY stats_CrdR stats_xG stats_npxG stats_xAG  \
# 443           0          1          0      0.3        0.3       0.1
# 434           0          1          0      1.8        1.8       1.3
#
#     stats_npxG+xAG stats_PrgC stats_PrgP stats_PrgR stats_G+A-PK stats_xG+xAG  \
# ...
